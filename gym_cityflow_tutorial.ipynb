# %%
# !pip install stable-baselines3
# print(gym.__version__)

# %% [markdown]
# ## Import relevant libraries

# %%
# import gym_cityflow
# from gym_cityflow.envs import Cityflow
import gym
import sys
import os
import random
import cityflow
import numpy as np
import json

from gym import spaces
from stable_baselines3 import A2C
from stable_baselines3 import DQN
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

# %% [markdown]
# ## Create gym environment for Cityflow

# %%
'''
action space = num of lighPhases


                |
                |
                N
                |
                |
------W----[][][][][]-------E-------
                |
                |
                S
                |
                |


go straight (W/E), (N/S)
straight + right (N), (S), (E), (W)
right only (W/E), (N/S)

total 8 phases
################################################################

observation space = [for each intersection[for each phase [num of incoming vehicles for each phase, avg speed for that phase]]]

################################################################

needs to be a way to extract number of lightPhases for each intersection (done, roadnet file)

'''
# Out:
# '\naction space = num of lighPhases\n\n\n                |\n                |\n                N\n                |\n                |\n------W----[][][][][]-------E-------\n                |\n                |\n                S\n                |\n                |\n\n\ngo straight (W/E), (N/S)\nstraight + right (N), (S), (E), (W)\nright only (W/E), (N/S)\n\ntotal 8 phases\n################################################################\n\nobservation space = [for each intersection[for each phase [num of incoming vehicles for each phase, avg speed for that phase]]]\n\n################################################################\n\nneeds to be a way to extract number of lightPhases for each intersection (done, roadnet file)\n\n'

# %%
class cityFlowGym(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, config_path, episodeSteps):
        
        # edit config_path to change replayLogFile name for each step
#         with open(config_path, "r+") as jsonFile:
#             data = json.load(jsonFile)
#             fileName = data["replayLogFile"].split(".")[0]
#             data["replayLogFile"] = fileName + "_" + str(replayNumber) + ".txt"

#             jsonFile.seek(0)  # rewind
#             json.dump(data, jsonFile)
        
        # creating Cityflow engine
        self.engine = cityflow.Engine(config_path, thread_num=1)
        
        #open cityflow config file into dict
        self.configDict = json.load(open(config_path))
        #open cityflow roadnet file into dict
        self.roadnetDict = json.load(open(self.configDict['dir'] + self.configDict['roadnetFile']))
        self.flowDict = json.load(open(self.configDict['dir'] + self.configDict['flowFile']))
        
        #steps per episode
#         self.steps_per_episode = episodeSteps
        self.isDone = False
        self.currStep = 0
        self.maxStep = episodeSteps
        self.minLighphaseTime = 0 #approximate realistic time
        self.maxLighphaseTime = 60 #approximate realistic time
        self.maxSpeed = self.flowDict[0]["vehicle"]["maxSpeed"]
        self.info = {}
        self.maxLightPhase = 0
        
        # create dict of controllable intersections and number of light phases
        self.intersections = {}
        for i in range(len(self.roadnetDict['intersections'])):
            # check if intersection is controllable
            if self.roadnetDict['intersections'][i]['virtual'] == False:
                currIntersection = self.roadnetDict['intersections'][i]
                
                # change maxLightPhase if needed for observationSpace definition
                if self.maxLightPhase < len(currIntersection['trafficLight']['lightphases']):
                    self.maxLightPhase = len(currIntersection['trafficLight']['lightphases'])
                
                # create incoming roadlink key that contains all incoming road lane id for each roadLink index
                roadLinkIntersectionDict = {}
                for roadLinkIndex, roadLink in enumerate(currIntersection["roadLinks"]):
                    startRoad = currIntersection["roadLinks"][roadLinkIndex]["startRoad"]
                    roadLinkSet = set()
                    for laneLinkIndex, laneLink in enumerate(currIntersection["roadLinks"][roadLinkIndex]["laneLinks"]):
                        tempLaneLink = startRoad + "_" + str(laneLink["startLaneIndex"])
                        roadLinkSet.add(tempLaneLink)
                    roadLinkIntersectionDict[roadLinkIndex] = roadLinkSet
                    
                # using the roadLinkIntersectionDict, we create the incoming road lanes and store it to each lightphase    
                lightPhaseRoadLaneIntersectionDict = {}
                for lightPhase in range(len(currIntersection['trafficLight']['lightphases'])):
                    availableRoadLinks = set()
                    for roadLinkIndex in currIntersection['trafficLight']['lightphases'][lightPhase]["availableRoadLinks"]:
                        availableRoadLinks.update(roadLinkIntersectionDict[roadLinkIndex])
                    lightPhaseRoadLaneIntersectionDict[lightPhase] = availableRoadLinks
                
#                 # for each roadLink in intersection store incoming lanes, outgoing lanes and direction in lists
#                 incomingLanes = []
#                 outgoingLanes = []
#                 directions = []
#                 for j in range(len(self.roadnetDict['intersections'][i]['roadLinks'])):
#                     incomingRoads = []
#                     outgoingRoads = []
#                     directions.append(self.roadnetDict['intersections'][i]['roadLinks'][j]['direction'])
#                     for k in range(len(self.roadnetDict['intersections'][i]['roadLinks'][j]['laneLinks'])):
#                         incomingRoads.append(self.roadnetDict['intersections'][i]['roadLinks'][j]['startRoad'] + 
#                                             '_' + 
#                                             str(self.roadnetDict['intersections'][i]['roadLinks'][j]['laneLinks'][k]['startLaneIndex']))
#                         outgoingRoads.append(self.roadnetDict['intersections'][i]['roadLinks'][j]['endRoad'] + 
#                                             '_' + 
#                                             str(self.roadnetDict['intersections'][i]['roadLinks'][j]['laneLinks'][k]['endLaneIndex']))
#                     incomingLanes.append(incomingRoads)
#                     outgoingLanes.append(outgoingRoads)

                # add intersection to dict where key = intersection_id
                # value = no of lightPhases, incoming lane names, outgoing lane names, directions for each lane group
                self.intersections[self.roadnetDict['intersections'][i]['id']] = { 
#                     "lightPhases" : len(self.roadnetDict['intersections'][i]['trafficLight']['lightphases']),
                    "lightPhases" : lightPhaseRoadLaneIntersectionDict,
                    "incomingRoadLinks" : roadLinkIntersectionDict
#                     "incomingLanes" : incomingLanes,
#                     "outgoingLanes" : outgoingLanes,
#                     "directions" : directions
                }
        
        #setup intersectionNames list for agent actions
        self.intersectionNames = []
        for key in self.intersections:
            self.intersectionNames.append(key)
        
        #define action space (num of lightPhases for each intersection) MultiDiscrete()
        actionSpaceArray = []
        upperBound = []
        for intersection in self.intersections:
#             lightphaseSpace = spaces.Discrete(len(self.intersections[intersection]["lightPhases"]))
#             lightphaseDurationSpace = spaces.Box(low = 0, high=60, shape=(1,), dtype=np.int32) # will +1 to get actual time
#             actionSpaceArray.append([lightphaseSpace.n, lightphaseDurationSpace.high[0]])

#             lightphaseSpace = spaces.Discrete(len(self.intersections[intersection]["lightPhases"]))
#             lightphaseDurationSpace = spaces.Box(low = 0, high=60, shape=(1,), dtype=np.int32) # will +1 to get actual time
#             actionSpaceArray.append([lightphaseSpace, lightphaseDurationSpace])

            
            upperBound.append(len(self.intersections[intersection]["lightPhases"]))
            upperBound.append(self.maxLighphaseTime)
#             lightphaseDurationSpace = self.minLighphaseTime = 0 #approximate realistic time
        

        self.action_space = spaces.Box(
            np.array([0 for space in range(len(upperBound))]).astype(np.int32),
            np.array(upperBound).astype(np.int32),
            dtype = np.int32
        )
        
        # define observation space
        '''
        (for 1 intersection) for 1 light phase = spaces.Dict({"numVehicles" : box(0, np.inf, (1,), dtype=np.int32),
                            "numWaitingVehicles" : box(0, np.inf, (1,), dtype=np.int32),
                             "avgSpeed" : box(0, np.inf, (1,), dtype=np.float32)})
                             
        (for 1 intersection) for n light phase = spaces.Dict({"numVehicles" : box(0, np.inf, (n,), dtype=np.int32),
                            "numWaitingVehicles" : box(0, np.inf, (1,), dtype=np.int32),
                             "avgSpeed" : box(0, np.inf, (n,), dtype=np.float32)})
                             
        (for n intersection) for n light phase = spaces.Dict({"intersection_1_1" : 
                                                    spaces.Dict({"numVehicles" : box(0, np.inf, (n,), dtype=np.int32),
                                                    "numWaitingVehicles" : box(0, np.inf, (1,), dtype=np.int32),
                                                     "avgSpeed" : box(0, np.inf, (n,), dtype=np.float32)})})
        '''
#         4th Iteration
        numOfIntersections = len(self.intersectionNames)
        observationSpace = {
                "numVehicles" : spaces.Box(0, np.inf, (numOfIntersections, self.maxLightPhase), dtype=np.int32),
                "numWaitingVehicles" : spaces.Box(0, np.inf, (numOfIntersections, self.maxLightPhase), dtype=np.int32),
                "avgSpeed" : spaces.Box(0, np.inf, (numOfIntersections, self.maxLightPhase), dtype=np.float32)

            }
        
        self.observation_space = spaces.Dict(observationSpace)
        
        
#         Applies for 3rd iteration
#         observationSpace = {}
#         for intersection in self.intersections:
#             numLightphases = len(self.intersections[intersection]["lightPhases"])
#             intersectionDict = spaces.Dict(
#                 {
#                     "numVehicles" : spaces.Box(0, np.inf, (numLightphases,), dtype=np.int32),
#                     "numWaitingVehicles" : spaces.Box(0, np.inf, (numLightphases,), dtype=np.int32),
#                     "avgSpeed" : spaces.Box(0, np.inf, (numLightphases,), dtype=np.float32)
                    
#                 }
#             )
#             observationSpace[intersection] = intersectionDict
        
#         self.observation_space = spaces.Dict(observationSpace)
        
        # create dictionary linking roadlane id to roadlinks for each intersection
#         for intersection in self.intersections:
#             roadLinkIntersectionDict = {}
#             for roadLinkIndex, roadLink in enumerate(self.intersections[intersection]["roadLinks"]):
#                 startRoad = self.intersections[intersection]["roadLinks"][roadLinkIndex]["startRoad"]
#                 roadLinkSet = set()
#                 for laneLinkIndex, laneLink in enumerate(self.intersections[intersection]["roadLinks"]["laneLinks"]):
#                     tempLaneLink = startRoad + "_" + str(laneLink["startLaneIndex"])
#                     roadLinkSet.add(tempLaneLink)
#                 roadLinkIntersectionDict[roadLinkIndex] = roadLinkSet
#             self.intersection[intersection]["incomingRoadLinks"] = roadLinkIntersectionDict
            
                
#         self.end_time = 3600
#         self.time_range = np.arange(self.start_time, self.end_time, self.step_len)
#         self.num_steps = len(self.time_range)
#         self.observation_space = gym.spaces.Box(
#             low=0, high=1, shape=(self.engine.get_num_of_intersections(), 2), dtype=np.float32)
#         self.action_space = gym.spaces.Discrete(self.engine.get_num_of_phases())
#         self.intersection_id = 0

    def step(self, action):
        
        # space.multidiscrete(tuple(space.discrete (lightPhase), space.box(duration of lightphase)) (for each intersection))
        actionArr = np.ndarray.tolist(action)
        minTimer = -1
        negRewards = False
        for intersection in range(len(self.intersectionNames)):
            
            # check if lightphase in intersection
            if actionArr[intersection*2] <= len(self.intersections[self.intersectionNames[intersection]]["lightPhases"]):
                self.engine.set_tl_phase(self.intersectionNames[intersection], int(actionArr[intersection*2]))
                if actionArr[1+intersection*2] < minTimer:
                    minTimer = intersection[1]
                    
            else:
                negRewards = True
#         for curr, intersection in enumerate(actionArr):
#             self.engine.set_tl_phase(self.intersectionNames[curr], intersection[0])
#             if intersection[1] < minTimer:
#                 minTimer = intersection[1]
                
        # let scenario run for minTimer long
        for second in range(minTimer):
            self.engine.next_step()
        
#         obs = np.concatenate((self.engine.get_lane_vehicle_count().reshape(-1, 1), self.engine.get_lane_speed().reshape(-1, 1)), axis=1) / 100
#         reward = self.engine.get_reward()
        obs = self.get_observation()
        reward = self.get_reward(obs, negRewards)
        self.isDone = self.currStep >= self.maxStep
        info = {}
        self.currStep += 1
        return obs, reward, self.isDone, info
    
    def get_observation(self):
        # get waiting vehicles for each lane first (key = laneID, value = numVehiclesWaiting)
        vehiclesWaitingByLaneDict = self.engine.get_lane_waiting_vehicle_count()
#         print(vehiclesWaitingByLaneDict)
        
        # get all vehicles speed (key = vehId, value = speed)
        vehiclesSpeedDict = self.engine.get_vehicle_speed()
#         print(vehiclesSpeedDict)
        
        # get all vehicles for each lane (key = laneId, value = [vehId])
        vehicleLaneDict = self.engine.get_lane_vehicles()
#         print(vehicleLaneDict)
        
        # create observation space for number of waiting vehicles and avgSpeed of moving+waiting vehicles of each lane
        # , for each lightphase
        
        # create for each roadlane first
        '''
        for roadLaneDict = {intersectionId : 
                                {roadLaneId: 
                                    {"numVehicles" : int,
                                     "numWaitingVehicles" : int,
                                     "avgSpeed" : float
                                                
                                    }
                
                                }
        
                            }
        '''
        roadLaneDict = {}
        for intersectionId, intersectionValue in self.intersections.items():
            roadLaneByIntersectionDict = {}
            
            # get a set of all incoming roadlanes for the intersection
            roadLaneByIntersectionSet = set()
            for roadLane in intersectionValue["incomingRoadLinks"].values():
                roadLaneByIntersectionSet.update(roadLane)
            
            # for each roadlane, find out num of waiting vehicles, and vehicles (waiting + nonwaiting) with speed
            for roadLane in roadLaneByIntersectionSet:
                tempRoadLaneDict = {}
                tempVehiclesArr = vehicleLaneDict[roadLane]
                tempRoadLaneDict["numVehicles"] = len(tempVehiclesArr)
                tempRoadLaneDict["numWaitingVehicles"] = vehiclesWaitingByLaneDict[roadLane]
                if len(tempVehiclesArr) == 0:
                    tempRoadLaneDict["avgSpeed"] = 0
                else:
                    tempAvgSpeed = 0
                    for vehicle in tempVehiclesArr:
                        tempAvgSpeed += vehiclesSpeedDict[vehicle]
                    tempRoadLaneDict["avgSpeed"] = tempAvgSpeed/len(tempVehiclesArr)
                
                roadLaneByIntersectionDict[roadLane] = tempRoadLaneDict
                
            # add intersection to roadLaneDict
            roadLaneDict[intersectionId] = roadLaneByIntersectionDict
        
        
        
        # define observation space
        '''
        1st iteration
        (for 1 intersection) for 1 light phase = spaces.Dict({"numVehicles" : box(0, np.inf, (1,), dtype=np.int32),
                            "numWaitingVehicles" : box(0, np.inf, (1,), dtype=np.int32),
                             "avgSpeed" : box(0, np.inf, (1,), dtype=np.float32)})
        2nd iteration                     
        (for 1 intersection) for n light phase = spaces.Dict({"numVehicles" : box(0, np.inf, (n,), dtype=np.int32),
                            "numWaitingVehicles" : box(0, np.inf, (n,), dtype=np.int32),
                             "avgSpeed" : box(0, np.inf, (n,), dtype=np.float32)})
        
        3rd iteration 
        (for n intersection) for n light phase = spaces.Dict({"intersection_1_1" : 
                                                    spaces.Dict({"numVehicles" : box(0, np.inf, (n,), dtype=np.int32),
                                                    "numWaitingVehicles" : box(0, np.inf, (n,), dtype=np.int32),
                                                     "avgSpeed" : box(0, np.inf, (n,), dtype=np.float32)})})
                                                     
        3rd definition of observation space does not work
        
        4th iteration
        (for m intersection) for n light phase = spaces.Dict({"numVehicles" : box(0, np.inf, (m,n), dtype=np.int32),
                                                    "numWaitingVehicles" : box(0, np.inf, (m,n), dtype=np.int32),
                                                     "avgSpeed" : box(0, np.inf, (m,n), dtype=np.float32)})})
                                                     
                                                     
        '''
        # observation for 4th iteration
        observationSpace = {
                "numVehicles" : [],
                "numWaitingVehicles" : [],             
                "avgSpeed" : []
            }
        
        # for each intersection 
        for intersectionId, intersectionValue in self.intersections.items():
            numVehiclesArr = []
            numWaitingVehiclesArr = []             
            avgSpeedArr = []
            
            # for each lightphase in the intersection
            for lightPhase, roadLaneArr in intersectionValue["lightPhases"].items():
                totalVehiclesByPhase = 0
                waitingVehiclesByPhase = 0
                totalSpeedByPhase = 0
                
                # for each roadLane (availableRoadLinks) in each lightphase
                for roadLaneId in roadLaneArr:
                    totalVehiclesByPhase += roadLaneDict[intersectionId][roadLaneId]["numVehicles"]
                    waitingVehiclesByPhase += roadLaneDict[intersectionId][roadLaneId]["numWaitingVehicles"]
                    totalSpeedByPhase += (roadLaneDict[intersectionId][roadLaneId]["numVehicles"] * 
                                          roadLaneDict[intersectionId][roadLaneId]["avgSpeed"])
                    
                # error checking if theres no vehicles in the lane to eliminate divide by zero error
                if totalVehiclesByPhase == 0:
                    avgSpeedByPhase = 0
                else:
                    avgSpeedByPhase = totalSpeedByPhase/totalVehiclesByPhase
                    
                numVehiclesArr.append(totalVehiclesByPhase)
                numWaitingVehiclesArr.append(waitingVehiclesByPhase)
                avgSpeedArr.append(avgSpeedByPhase)
                
            # convert to np array
            tempNumVehicles = np.array(numVehiclesArr)
            tempNumWaitingVehicles = np.array(numWaitingVehiclesArr)
            tempAvgSpeed = np.array(avgSpeedArr)
            
            observationSpace["numVehicles"].append(tempNumVehicles)
            observationSpace["numWaitingVehicles"].append(tempNumWaitingVehicles)
            observationSpace["avgSpeed"].append(tempAvgSpeed)
                
        # convert to np array
        observationSpace["numVehicles"] = np.array(observationSpace["numVehicles"])
        observationSpace["numWaitingVehicles"] = np.array(observationSpace["numWaitingVehicles"])
        observationSpace["avgSpeed"] = np.array(observationSpace["avgSpeed"])
        
#         print(observationSpace)
        return observationSpace
        
        
        # 3rd iteration (to be used for reference)
        # create obs dict to return function call
#         observationSpace = {}
        
#         # for each intersection 
#         for intersectionId, intersectionValue in self.intersections.items():
#             intersectionObsDict = {
#                 "numVehicles" : [],
#                 "numWaitingVehicles" : [],             
#                 "avgSpeed" : []
#             }
            
#             # for each lightphase in the intersection
#             for lightPhase, roadLaneArr in intersectionValue["lightPhases"].items():
#                 totalVehiclesByPhase = 0
#                 waitingVehiclesByPhase = 0
#                 totalSpeedByPhase = 0
                
#                 # for each roadLane (availableRoadLinks) in each lightphase
#                 for roadLaneId in roadLaneArr:
#                     totalVehiclesByPhase += roadLaneDict[intersectionId][roadLaneId]["numVehicles"]
#                     waitingVehiclesByPhase += roadLaneDict[intersectionId][roadLaneId]["numWaitingVehicles"]
#                     totalSpeedByPhase += (roadLaneDict[intersectionId][roadLaneId]["numVehicles"] * 
#                                           roadLaneDict[intersectionId][roadLaneId]["avgSpeed"])
                    
#                 # error checking if theres no vehicles in the lane to eliminate divide by zero error
#                 if totalVehiclesByPhase == 0:
#                     avgSpeedByPhase = 0
#                 else:
#                     avgSpeedByPhase = totalSpeedByPhase/totalVehiclesByPhase
                    
#                 intersectionObsDict["numVehicles"].append(totalVehiclesByPhase)
#                 intersectionObsDict["numWaitingVehicles"].append(waitingVehiclesByPhase)
#                 intersectionObsDict["avgSpeed"].append(avgSpeedByPhase)
                
#                 # convert to np array
#                 intersectionObsDict["numVehicles"] = np.array(intersectionObsDict["numVehicles"])
#                 ntersectionObsDict["numWaitingVehicles"] = np.array(intersectionObsDict["numWaitingVehicles"])
#                 ntersectionObsDict["avgSpeed"] = np.array(intersectionObsDict["avgSpeed"])
                
#             observationSpace[intersectionId] = intersectionObsDict
                        
#         return observationSpace
        
    def get_reward(self, observationSpace, negRewards):
        
        # if model returns lightphase that is not possible
        if negRewards == True:
            return -np.inf
        # aggregate total reward from all intersections
        totalReward = 0
        
        # numVehicles reward calc
        for intersection in observationSpace["numVehicles"]:
            for veh in intersection:
                
                totalReward -= veh
#                 print("veh", totalReward)
                
        # numWaitingVehicles reward calc
        for intersection in observationSpace["numWaitingVehicles"]:
            for waitingVeh in intersection:
                if waitingVeh == 0:
                        totalReward += 100
                else:
                    totalReward -= waitingVeh*100
#                 print("waitingVeh", totalReward)
                    
                        
        # avgSpeed reward calc
        for intersection in observationSpace["numWaitingVehicles"]:
            for speed in intersection:
                
                #reward if speed is
                if (speed-5) >= self.maxSpeed:
                    totalReward += 50
                else:
                    totalReward -= ((self.maxSpeed - speed)/self.maxSpeed)*50
#                 print("speed", totalReward)
        
            
        return totalReward/len(self.intersectionNames)
            
    def reset(self):
#         self.engine.reset()
        self.currStep = 0
        obs = self.get_observation()
#         print("obs", obs)
        self.isDone = False
        return obs
    

    def render(self, mode='human', close=False):
        pass

# %%
# cityflowEnv = DummyVecEnv([lambda: cityFlowGym("sample_data/jacob_config.json", 3600)])

# %%
cityflowEnv = cityFlowGym("sample_data/jacob_config.json", 3600)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MultiInputPolicy", cityflowEnv, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000000)
# Out:
# Logging to Training/Logs/PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 1487 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 665           |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.1109281e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.25e+07      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -9.25e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.46e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 735           |
# |    iterations           | 3             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 5.7524885e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.24e+07      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -4.1e-05      |
# |    std                  | 1             |
# |    value_loss           | 4.4e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 784           |
# |    iterations           | 4             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.6832433e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.21e+07      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000207     |
# |    std                  | 1             |
# |    value_loss           | 4.46e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 813           |
# |    iterations           | 5             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 5.3706462e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.24e+07      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -4.72e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.4e+07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 7.345021e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+07     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 5.36e-05     |
# |    std                  | 1.01         |
# |    value_loss           | 4.45e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 1.106484e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22e+07     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -9.17e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 4.4e+07      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 873           |
# |    iterations           | 8             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 2.5343907e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.25e+07      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -2.94e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 4.45e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 859           |
# |    iterations           | 9             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 4.4000335e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.16e+07      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -2.93e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 4.4e+07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 10           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 8.905772e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23e+07     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -6.72e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 4.39e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 823           |
# |    iterations           | 11            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.1670985e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+07      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.000106      |
# |    std                  | 1.01          |
# |    value_loss           | 4.45e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 812           |
# |    iterations           | 12            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.6117934e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.15e+07      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000105     |
# |    std                  | 1.01          |
# |    value_loss           | 4.39e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 804           |
# |    iterations           | 13            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 1.1110387e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+07      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -9.94e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.44e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 797           |
# |    iterations           | 14            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 5.2131363e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+07      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -4.12e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.39e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 794           |
# |    iterations           | 15            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 2.9876537e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.24e+07      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | 0.00652       |
# |    std                  | 1.01          |
# |    value_loss           | 4.44e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 790           |
# |    iterations           | 16            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 5.3255935e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.21e+07      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -3.62e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.39e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 786           |
# |    iterations           | 17            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 5.8660225e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.16e+07      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -5.31e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.38e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 18           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 3.012683e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23e+07     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000206    |
# |    std                  | 1            |
# |    value_loss           | 4.44e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 783          |
# |    iterations           | 19           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 4.532223e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+07     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -4.67e-05    |
# |    std                  | 1            |
# |    value_loss           | 4.38e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 778           |
# |    iterations           | 20            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 4.0279992e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.24e+07      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.000164      |
# |    std                  | 1             |
# |    value_loss           | 4.43e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 764           |
# |    iterations           | 21            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 3.5664707e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+07      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -1.64e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.38e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 22           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 9.594223e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2e+07      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00251     |
# |    std                  | 1            |
# |    value_loss           | 4.43e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 737           |
# |    iterations           | 23            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.2727163e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.13e+07      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00011      |
# |    std                  | 1             |
# |    value_loss           | 4.38e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 24           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 9.126292e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18e+07     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -6.34e-05    |
# |    std                  | 1            |
# |    value_loss           | 4.37e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 718           |
# |    iterations           | 25            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 8.5661304e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.24e+07      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -8.68e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.43e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 712           |
# |    iterations           | 26            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 3.6794809e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+07      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -2.41e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.37e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 707           |
# |    iterations           | 27            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.1542521e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.23e+07      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000139     |
# |    std                  | 1             |
# |    value_loss           | 4.42e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 702           |
# |    iterations           | 28            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.3419078e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.11e+07      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000113     |
# |    std                  | 1             |
# |    value_loss           | 4.37e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 701           |
# |    iterations           | 29            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 2.8982438e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.19e+07      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000341     |
# |    std                  | 0.999         |
# |    value_loss           | 4.42e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 697           |
# |    iterations           | 30            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 1.3711193e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.19e+07      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000106     |
# |    std                  | 0.998         |
# |    value_loss           | 4.37e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 686           |
# |    iterations           | 31            |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 3.8091937e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.16e+07      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000271     |
# |    std                  | 0.999         |
# |    value_loss           | 4.37e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 682           |
# |    iterations           | 32            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 1.1982338e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.2e+07       |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.00248      |
# |    std                  | 0.999         |
# |    value_loss           | 4.42e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 681          |
# |    iterations           | 33           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 2.075656e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22e+07     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -1.62e-05    |
# |    std                  | 0.999        |
# |    value_loss           | 4.36e+07     |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 3.6e+03        |
# |    ep_rew_mean          | 1.44e+06       |
# | time/                   |                |
# |    fps                  | 681            |
# |    iterations           | 34             |
# |    time_elapsed         | 102            |
# |    total_timesteps      | 69632          |
# | train/                  |                |
# |    approx_kl            | 1.14529685e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | 1.79e-07       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.22e+07       |
# |    n_updates            | 330            |
# |    policy_gradient_loss | -9.93e-05      |
# |    std                  | 1              |
# |    value_loss           | 4.41e+07       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 678           |
# |    iterations           | 35            |
# |    time_elapsed         | 105           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.6691629e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.18e+07      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -9.82e-06     |
# |    std                  | 1             |
# |    value_loss           | 4.36e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 670          |
# |    iterations           | 36           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 9.127863e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.16e+07     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 6.29e-05     |
# |    std                  | 0.999        |
# |    value_loss           | 4.41e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.6e+03     |
# |    ep_rew_mean          | 1.44e+06    |
# | time/                   |             |
# |    fps                  | 668         |
# |    iterations           | 37          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 9.31992e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15e+07    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -5.93e-05   |
# |    std                  | 1           |
# |    value_loss           | 4.36e+07    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 666           |
# |    iterations           | 38            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 2.7823553e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+07      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000174     |
# |    std                  | 0.997         |
# |    value_loss           | 4.36e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 664           |
# |    iterations           | 39            |
# |    time_elapsed         | 120           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 1.3779209e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.19e+07      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.00251      |
# |    std                  | 0.997         |
# |    value_loss           | 4.41e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 666           |
# |    iterations           | 40            |
# |    time_elapsed         | 122           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 3.9896404e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.21e+07      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -2.48e-05     |
# |    std                  | 0.997         |
# |    value_loss           | 4.35e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 667           |
# |    iterations           | 41            |
# |    time_elapsed         | 125           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 1.6432605e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.21e+07      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000754     |
# |    std                  | 0.998         |
# |    value_loss           | 4.4e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 669           |
# |    iterations           | 42            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 1.9467057e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+07      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000119     |
# |    std                  | 0.996         |
# |    value_loss           | 4.35e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 671           |
# |    iterations           | 43            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 3.3203105e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.18e+07      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -6.93e-05     |
# |    std                  | 0.996         |
# |    value_loss           | 4.4e+07       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.6e+03     |
# |    ep_rew_mean          | 1.44e+06    |
# | time/                   |             |
# |    fps                  | 673         |
# |    iterations           | 44          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 8.83147e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16e+07    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -6.52e-05   |
# |    std                  | 0.995       |
# |    value_loss           | 4.35e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 45           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 2.584362e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.16e+07     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -1.75e-05    |
# |    std                  | 0.995        |
# |    value_loss           | 4.35e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 676           |
# |    iterations           | 46            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 3.4007826e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+07      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 0.00013       |
# |    std                  | 0.995         |
# |    value_loss           | 4.4e+07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 677           |
# |    iterations           | 47            |
# |    time_elapsed         | 142           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 1.7998391e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+07      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -1.69e-05     |
# |    std                  | 0.995         |
# |    value_loss           | 4.34e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 679           |
# |    iterations           | 48            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 2.3762404e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+07      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000239     |
# |    std                  | 0.995         |
# |    value_loss           | 4.4e+07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 680          |
# |    iterations           | 49           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 5.410664e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.17e+07     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -6.49e-05    |
# |    std                  | 0.993        |
# |    value_loss           | 4.34e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 682          |
# |    iterations           | 50           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 8.271891e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.21e+07     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | 0.000122     |
# |    std                  | 0.995        |
# |    value_loss           | 4.39e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 683           |
# |    iterations           | 51            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 1.1342578e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# ...
# |    total_timesteps      | 968704        |
# | train/                  |               |
# |    approx_kl            | 1.1039287e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.84e+07      |
# |    n_updates            | 4720          |
# |    policy_gradient_loss | -7.13e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 3.77e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 474           |
# |    time_elapsed         | 1469          |
# |    total_timesteps      | 970752        |
# | train/                  |               |
# |    approx_kl            | 9.4345305e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.9e+07       |
# |    n_updates            | 4730          |
# |    policy_gradient_loss | -8.61e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 3.77e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 475          |
# |    time_elapsed         | 1472         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 8.097617e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.89e+07     |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -8.88e-05    |
# |    std                  | 1.02         |
# |    value_loss           | 3.82e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 476           |
# |    time_elapsed         | 1475          |
# |    total_timesteps      | 974848        |
# | train/                  |               |
# |    approx_kl            | 3.4789875e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.83e+07      |
# |    n_updates            | 4750          |
# |    policy_gradient_loss | -0.000216     |
# |    std                  | 1.02          |
# |    value_loss           | 3.77e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 477           |
# |    time_elapsed         | 1479          |
# |    total_timesteps      | 976896        |
# | train/                  |               |
# |    approx_kl            | 5.3611293e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.93e+07      |
# |    n_updates            | 4760          |
# |    policy_gradient_loss | -0.000399     |
# |    std                  | 1.02          |
# |    value_loss           | 3.82e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 478          |
# |    time_elapsed         | 1482         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 8.971285e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+07      |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -7.04e-05    |
# |    std                  | 1.02         |
# |    value_loss           | 3.76e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 479          |
# |    time_elapsed         | 1485         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 8.416071e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.88        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+07     |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00011     |
# |    std                  | 1.02         |
# |    value_loss           | 3.82e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 480           |
# |    time_elapsed         | 1488          |
# |    total_timesteps      | 983040        |
# | train/                  |               |
# |    approx_kl            | 1.5036785e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.83e+07      |
# |    n_updates            | 4790          |
# |    policy_gradient_loss | -8.03e-06     |
# |    std                  | 1.02          |
# |    value_loss           | 3.76e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 481           |
# |    time_elapsed         | 1491          |
# |    total_timesteps      | 985088        |
# | train/                  |               |
# |    approx_kl            | 6.0806633e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.93e+07      |
# |    n_updates            | 4800          |
# |    policy_gradient_loss | -5.45e-06     |
# |    std                  | 1.02          |
# |    value_loss           | 3.82e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 482           |
# |    time_elapsed         | 1494          |
# |    total_timesteps      | 987136        |
# | train/                  |               |
# |    approx_kl            | 3.2849464e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.89e+07      |
# |    n_updates            | 4810          |
# |    policy_gradient_loss | -0.000193     |
# |    std                  | 1.03          |
# |    value_loss           | 3.77e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 483           |
# |    time_elapsed         | 1497          |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 5.5343553e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.84e+07      |
# |    n_updates            | 4820          |
# |    policy_gradient_loss | -3.77e-05     |
# |    std                  | 1.03          |
# |    value_loss           | 3.76e+07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 484          |
# |    time_elapsed         | 1500         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 3.596564e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+07     |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | 0.000384     |
# |    std                  | 1.03         |
# |    value_loss           | 3.81e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.6e+03      |
# |    ep_rew_mean          | 1.44e+06     |
# | time/                   |              |
# |    fps                  | 660          |
# |    iterations           | 485          |
# |    time_elapsed         | 1504         |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 6.033224e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85e+07     |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -3.89e-05    |
# |    std                  | 1.03         |
# |    value_loss           | 3.75e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 486           |
# |    time_elapsed         | 1507          |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 1.2657343e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.92e+07      |
# |    n_updates            | 4850          |
# |    policy_gradient_loss | 4.84e-05      |
# |    std                  | 1.02          |
# |    value_loss           | 3.81e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 487           |
# |    time_elapsed         | 1510          |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 5.9169543e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.89e+07      |
# |    n_updates            | 4860          |
# |    policy_gradient_loss | -3.67e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 3.75e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 488           |
# |    time_elapsed         | 1513          |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 5.2695104e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.92e+07      |
# |    n_updates            | 4870          |
# |    policy_gradient_loss | 0.000642      |
# |    std                  | 1.02          |
# |    value_loss           | 3.81e+07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 3.6e+03       |
# |    ep_rew_mean          | 1.44e+06      |
# | time/                   |               |
# |    fps                  | 660           |
# |    iterations           | 489           |
# |    time_elapsed         | 1516          |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 1.5476253e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.81e+07      |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | -7.74e-06     |
# |    std                  | 1.02          |
# |    value_loss           | 3.75e+07      |
# -------------------------------------------

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = cityflowEnv.reset()
#     cityflowEnv.engine.reset()
    done = False
    score = 0
    step = 0
    
    while not done:
#         env.render()
        action = cityflowEnv.action_space.sample()
        n_state, reward, done, info = cityflowEnv.step(action)
#         print(n_state, reward, done, info)
        
#         print(reward)
#         avg_reward = 0
#         for intersection in reward:
#             avg_reward += intersection[1]
#         avg_reward /= len(reward)
        score += reward
        step +=1
#         break
    score /= step
        
    print('Episode:{} Score:{} with {} steps'.format(episode, score, step))
# Out:
# Episode:1 Score:400.0 with 3601 steps
# Episode:2 Score:400.0 with 3601 steps
# Episode:3 Score:400.0 with 3601 steps
# Episode:4 Score:400.0 with 3601 steps
# Episode:5 Score:400.0 with 3601 steps
# Episode:6 Score:400.0 with 3601 steps
# Episode:7 Score:400.0 with 3601 steps
# Episode:8 Score:400.0 with 3601 steps
# Episode:9 Score:400.0 with 3601 steps
# Episode:10 Score:400.0 with 3601 steps

# %%
# It will check your custom environment and output additional warnings if needed
check_env(cityflowEnv)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/env_checker.py:155, in _check_returned_values(env, observation_space, action_space)
#     154 try:
# --> 155     _check_obs(obs[key], observation_space.spaces[key], "reset")
#     156 except AssertionError as e:
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/env_checker.py:112, in _check_obs(obs, observation_space, method_name)
#     110     assert isinstance(obs, np.ndarray), f"The observation returned by `{method_name}()` method must be a numpy array"
# --> 112 assert observation_space.contains(
#     113     obs
#     114 ), f"The observation returned by the `{method_name}()` method does not match the given observation space"
#
# AssertionError: The observation returned by the `reset()` method does not match the given observation space
#
# The above exception was the direct cause of the following exception:
#
# AssertionError                            Traceback (most recent call last)
# Cell In [155], line 2
#       1 # It will check your custom environment and output additional warnings if needed
# ----> 2 check_env(cityflowEnv)
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/env_checker.py:302, in check_env(env, warn, skip_render_check)
#     297         warnings.warn(
#     298             f"Your action space has dtype {action_space.dtype}, we recommend using np.float32 to avoid cast errors."
#     299         )
#     301 # ============ Check the returned values ===============
# --> 302 _check_returned_values(env, observation_space, action_space)
#     304 # ==== Check the render method and the declared render modes ====
#     305 if not skip_render_check:
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/env_checker.py:157, in _check_returned_values(env, observation_space, action_space)
#     155             _check_obs(obs[key], observation_space.spaces[key], "reset")
#     156         except AssertionError as e:
# --> 157             raise AssertionError(f"Error while checking key={key}: " + str(e)) from e
#     158 else:
#     159     _check_obs(obs, observation_space, "reset")
#
# AssertionError: Error while checking key=avgSpeed: The observation returned by the `reset()` method does not match the given observation space

# %%
# actionSpaceArray = []

# lightphaseSpace = spaces.Discrete(8)
# lightphaseDurationSpace = spaces.Box(low = 0, high=60, shape=(1,), dtype=np.float32)
# # intersection1 = gym.spaces.Tuple((lightphaseSpace.n, lightphaseDurationSpace[0]))
# actionSpaceArray.append([lightphaseSpace.n, lightphaseDurationSpace.high[0]])
# lightphaseSpace = spaces.Discrete(3)
# lightphaseDurationSpace = spaces.Box(low = 10, high=20, shape=(1,), dtype=np.int32)
# # intersection2 = gym.spaces.Tuple((lightphaseSpace.n, lightphaseDurationSpace[0]))
# actionSpaceArray.append([lightphaseSpace.n, lightphaseDurationSpace.high[0]])

# action_space = spaces.MultiDiscrete(actionSpaceArray)




# for intersection in self.intersections:
# lightphaseSpace = spaces.Discrete(8)
# lightphaseDurationSpace = spaces.Box(low = 10, high=60, shape=(1,), dtype=np.int32)
# actionSpaceArray.append([lightphaseSpace, lightphaseDurationSpace]) # tuple for each intersection (lightphase next, duration)
# lightphaseSpace = spaces.Discrete(3)
# lightphaseDurationSpace = spaces.Box(low = 10, high=20, shape=(1,), dtype=np.int32)
# actionSpaceArray.append([lightphaseSpace, lightphaseDurationSpace]) # tuple for each intersection (lightphase next, duration)

# actionSpaceArray.append([i for i in range(8)])
# actionSpaceArray.append([i for i in range(10,61)])
# actionSpaceArray.append([i for i in range(3)])
# actionSpaceArray.append([i for i in range(10,21)])
# action_space = spaces.MultiDiscrete(actionSpaceArray) # multidiscrete for all intersections

# lightphaseSpace = spaces.Discrete(8)
# lightphaseDurationSpace = spaces.Box(low = 10, high=60, shape=(1,), dtype=np.int32)
# actionSpaceArray.append(gym.spaces.MultiDiscrete([lightphaseSpace, lightphaseDurationSpace]))
# lightphaseSpace = spaces.Discrete(3)
# lightphaseDurationSpace = spaces.Box(low = 10, high=20, shape=(1,), dtype=np.int32)
# actionSpaceArray.append(gym.spaces.MultiDiscrete([lightphaseSpace, lightphaseDurationSpace]))

# action_space = spaces.MultiDiscrete(np.array(actionSpaceArray))

# action_space = spaces.MultiDiscrete(actionSpaceArray) # multidiscrete for all intersections


action_space = spaces.Box(
            np.array([0, 0, 0, 0]).astype(np.int32),
            np.array([8, 60, 3, 10]).astype(np.int32),
            dtype=np.int32
        )

# %%
# np.ndarray.tolist(action_space.sample())
# Out:
# [5, 1, 0, 5]

# %%
env = gym.make(
    "cityflow-v0",
    configPath="sample_data/jacob_config.json"
    ,episodeSteps=3600
)

# %%
env.getRoadnet()
# Out:
# Roadnet is from path: sample_data/jacob_flow.json

# %%
# vec_env = DummyVecEnv([lambda: env])

# %%
# Check action space
print(type(env.action_space))
print(type(env.observation_space))
print(env.action_space)
# Out:
# <class 'gym.spaces.multi_discrete.MultiDiscrete'>
# <class 'gym.spaces.dict.Dict'>
# MultiDiscrete([8])

# %%
print(env.action_space.sample())
# Out:
# [4]

# %%
print(env.actionSpaceArray)
# Out:
# [8]

# %%
print(env.intersections)
# Out:
# {'intersection_1_1': [[8], [['road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4'], ['road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1'], ['road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6'], ['road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6'], ['road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4'], ['road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1'], ['road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6'], ['road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4'], ['road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1'], ['road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1'], ['road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6'], ['road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4']], [['road_1_1_0_0', 'road_1_1_0_1', 'road_1_1_0_2', 'road_1_1_0_3', 'road_1_1_0_4', 'road_1_1_0_5', 'road_1_1_0_6', 'road_1_1_0_0', 'road_1_1_0_1', 'road_1_1_0_2', 'road_1_1_0_3', 'road_1_1_0_4', 'road_1_1_0_5', 'road_1_1_0_6', 'road_1_1_0_0', 'road_1_1_0_1', 'road_1_1_0_2', 'road_1_1_0_3', 'road_1_1_0_4', 'road_1_1_0_5', 'road_1_1_0_6'], ['road_1_1_1_0', 'road_1_1_1_1', 'road_1_1_1_2', 'road_1_1_1_3', 'road_1_1_1_4', 'road_1_1_1_5', 'road_1_1_1_6', 'road_1_1_1_0', 'road_1_1_1_1', 'road_1_1_1_2', 'road_1_1_1_3', 'road_1_1_1_4', 'road_1_1_1_5', 'road_1_1_1_6'], ['road_1_1_3_0', 'road_1_1_3_1', 'road_1_1_3_2', 'road_1_1_3_3', 'road_1_1_3_4', 'road_1_1_3_5', 'road_1_1_3_6', 'road_1_1_3_0', 'road_1_1_3_1', 'road_1_1_3_2', 'road_1_1_3_3', 'road_1_1_3_4', 'road_1_1_3_5', 'road_1_1_3_6'], ['road_1_1_0_0', 'ro ...

# %%
print(env.intersections["intersection_1_1"][1])
print(len(env.intersections["intersection_1_1"][1]))
# Out:
# [['road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4'], ['road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1'], ['road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6'], ['road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_5', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6', 'road_1_0_1_6'], ['road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_2', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_3', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4', 'road_1_0_1_4'], ['road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_0', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1', 'road_1_0_1_1'], ['road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_5', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6', 'road_2_1_2_6'], ['road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_2', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_3', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4', 'road_2_1_2_4'], ['road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_0', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1', 'road_2_1_2_1'], ['road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_0', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1', 'road_1_2_3_1'], ['road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_5', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6', 'road_1_2_3_6'], ['road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_2', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_3', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4', 'road_1_2_3_4']]
# 12

# %%
print(env.intersections["intersection_1_1"][1][0])
print(len(env.intersections["intersection_1_1"][1][0]))
print()
print(env.intersections["intersection_1_1"][1][1])
print(len(env.intersections["intersection_1_1"][1][1]))
print()
print(env.intersections["intersection_1_1"][1][2])
print(len(env.intersections["intersection_1_1"][1][2]))
# Out:
# ['road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_2', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_3', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4', 'road_0_1_0_4']
# 21
#
# ['road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_0', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1', 'road_0_1_0_1']
# 14
#
# ['road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_5', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6', 'road_0_1_0_6']
# 14

# %%
print(env.intersections["intersection_1_1"][2][0])
print(len(env.intersections["intersection_1_1"][2][0]))
print()
print(env.intersections["intersection_1_1"][2][1])
print(len(env.intersections["intersection_1_1"][2][1]))
print()
print(env.intersections["intersection_1_1"][2][2])
print(len(env.intersections["intersection_1_1"][2][2]))
# Out:
# ['road_1_1_0_0', 'road_1_1_0_1', 'road_1_1_0_2', 'road_1_1_0_3', 'road_1_1_0_4', 'road_1_1_0_5', 'road_1_1_0_6', 'road_1_1_0_0', 'road_1_1_0_1', 'road_1_1_0_2', 'road_1_1_0_3', 'road_1_1_0_4', 'road_1_1_0_5', 'road_1_1_0_6', 'road_1_1_0_0', 'road_1_1_0_1', 'road_1_1_0_2', 'road_1_1_0_3', 'road_1_1_0_4', 'road_1_1_0_5', 'road_1_1_0_6']
# 21
#
# ['road_1_1_1_0', 'road_1_1_1_1', 'road_1_1_1_2', 'road_1_1_1_3', 'road_1_1_1_4', 'road_1_1_1_5', 'road_1_1_1_6', 'road_1_1_1_0', 'road_1_1_1_1', 'road_1_1_1_2', 'road_1_1_1_3', 'road_1_1_1_4', 'road_1_1_1_5', 'road_1_1_1_6']
# 14
#
# ['road_1_1_3_0', 'road_1_1_3_1', 'road_1_1_3_2', 'road_1_1_3_3', 'road_1_1_3_4', 'road_1_1_3_5', 'road_1_1_3_6', 'road_1_1_3_0', 'road_1_1_3_1', 'road_1_1_3_2', 'road_1_1_3_3', 'road_1_1_3_4', 'road_1_1_3_5', 'road_1_1_3_6']
# 14

# %%
print(env.intersections["intersection_1_1"][3])
print(len(env.intersections["intersection_1_1"][3]))
# Out:
# [0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3]
# 12

# %%
env.flowDict
# Out:
# [{'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_0_1_0', 'road_1_1_0'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_2_1_2', 'road_1_1_2'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_1_0_1', 'road_1_1_1'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_1_2_3', 'road_1_1_3'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_1_0_1', 'road_1_1_0'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_0_1_0', 'road_1_1_1'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_2_1_2', 'road_1_1_3'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_1_2_3', 'road_1_1_2'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_0_1_0', 'road_1_1_3'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_1_2_3', 'road_1_1_0'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_2_1_2', 'road_1_1_1'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1},
#  {'vehicle': {'length': 5.0,
#    'width': 2.0,
#    'maxPosAcc': 2.0,
#    'maxNegAcc': 4.5,
#    'usualPosAcc': 2.0,
#    'usualNegAcc': 4.5,
#    'minGap': 2.5,
#    'maxSpeed': 16.67,
#    'headwayTime': 1.5},
#   'route': ['road_1_0_1', 'road_1_1_2'],
#   'interval': 5.0,
#   'startTime': 0,
#   'endTime': -1}]

# %%
len(env.flowDict)
# Out:
# 12

# %%
for i in range(len(env.intersections["intersection_1_1"][1])):
    print("New i " + str(i))
    for j in range(len(env.intersections["intersection_1_1"][1][i])):
        print("Start Road " + env.intersections["intersection_1_1"][1][i][j] + 
              " End Road " + env.intersections["intersection_1_1"][2][i][j])

# %%
# # disable print temporarily
# # iterate environment a lttle bit to test env
# actionInterval = 10


# for i in range(10):
#     if i % actionInterval == 0:
#         testAction = []
#         for i in range(0, 16):
#             n = random.randint(0, 8)
#             testAction.append(n)
#     observation, reward, done, debug = env.step(action=testAction)
#     if done:
#         break

# observation, reward, done, debug = env.step(action=testAction)
# print(observation)
# print(reward)

# observation = env.reset()
# print(observation)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    step = 0
    
    while not done:
#         env.render()
        step += 1
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        
        
        print(reward)
        avg_reward = 0
        for intersection in reward:
            avg_reward += intersection[1]
        avg_reward /= len(reward)
        score += avg_reward
        
    print('Episode:{} Score:{}'.format(episode, score))

# %%
print(n_state)

# %%
cityflowEnv = Cityflow("sample_data/jacob_config.json", 3600)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MultiInputPolicy", cityflowEnv, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 model = PPO("MultiInputPolicy", cityflowEnv, verbose=1, tensorboard_log=log_path)
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:167, in PPO.__init__(self, policy, env, learning_rate, n_steps, batch_size, n_epochs, gamma, gae_lambda, clip_range, clip_range_vf, normalize_advantage, ent_coef, vf_coef, max_grad_norm, use_sde, sde_sample_freq, target_kl, tensorboard_log, create_eval_env, policy_kwargs, verbose, seed, device, _init_setup_model)
#     164 self.target_kl = target_kl
#     166 if _init_setup_model:
# --> 167     self._setup_model()
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py:170, in PPO._setup_model(self)
#     169 def _setup_model(self) -> None:
# --> 170     super()._setup_model()
#     172     # Initialize schedules for policy/value clipping
#     173     self.clip_range = get_schedule_fn(self.clip_range)
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py:123, in OnPolicyAlgorithm._setup_model(self)
#     112 buffer_cls = DictRolloutBuffer if isinstance(self.observation_space, gym.spaces.Dict) else RolloutBuffer
#     114 self.rollout_buffer = buffer_cls(
#     115     self.n_steps,
#     116     self.observation_space,
#    (...)
#     121     n_envs=self.n_envs,
#     122 )
# --> 123 self.policy = self.policy_class(  # pytype:disable=not-instantiable
#     124     self.observation_space,
#     125     self.action_space,
#     126     self.lr_schedule,
#     127     use_sde=self.use_sde,
#     128     **self.policy_kwargs  # pytype:disable=not-instantiable
#     129 )
#     130 self.policy = self.policy.to(self.device)
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/policies.py:801, in MultiInputActorCriticPolicy.__init__(self, observation_space, action_space, lr_schedule, net_arch, activation_fn, ortho_init, use_sde, log_std_init, full_std, sde_net_arch, use_expln, squash_output, features_extractor_class, features_extractor_kwargs, normalize_images, optimizer_class, optimizer_kwargs)
#     781 def __init__(
#     782     self,
#     783     observation_space: gym.spaces.Dict,
#    (...)
#     799     optimizer_kwargs: Optional[Dict[str, Any]] = None,
#     800 ):
# --> 801     super().__init__(
#     802         observation_space,
#     803         action_space,
#     804         lr_schedule,
#     805         net_arch,
#     806         activation_fn,
#     807         ortho_init,
#     808         use_sde,
#     809         log_std_init,
#     810         full_std,
#     811         sde_net_arch,
#     812         use_expln,
#     813         squash_output,
#     814         features_extractor_class,
#     815         features_extractor_kwargs,
#     816         normalize_images,
#     817         optimizer_class,
#     818         optimizer_kwargs,
#     819     )
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/policies.py:483, in ActorCriticPolicy.__init__(self, observation_space, action_space, lr_schedule, net_arch, activation_fn, ortho_init, use_sde, log_std_init, full_std, sde_net_arch, use_expln, squash_output, features_extractor_class, features_extractor_kwargs, normalize_images, optimizer_class, optimizer_kwargs)
#     480 # Action distribution
#     481 self.action_dist = make_proba_distribution(action_space, use_sde=use_sde, dist_kwargs=dist_kwargs)
# --> 483 self._build(lr_schedule)
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/policies.py:540, in ActorCriticPolicy._build(self, lr_schedule)
#     533 def _build(self, lr_schedule: Schedule) -> None:
#     534     """
#     535     Create the networks and the optimizer.
#     536
#     537     :param lr_schedule: Learning rate schedule
#     538         lr_schedule(1) is the initial learning rate
#     539     """
# --> 540     self._build_mlp_extractor()
#     542     latent_dim_pi = self.mlp_extractor.latent_dim_pi
#     544     if isinstance(self.action_dist, DiagGaussianDistribution):
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/policies.py:526, in ActorCriticPolicy._build_mlp_extractor(self)
#     519 """
#     520 Create the policy and value networks.
#     521 Part of the layers can be shared.
#     522 """
#     523 # Note: If net_arch is None and some features extractor is used,
#     524 #       net_arch here is an empty list and mlp_extractor does not
#     525 #       really contain any layers (acts like an identity module).
# --> 526 self.mlp_extractor = MlpExtractor(
#     527     self.features_dim,
#     528     net_arch=self.net_arch,
#     529     activation_fn=self.activation_fn,
#     530     device=self.device,
#     531 )
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/stable_baselines3/common/torch_layers.py:204, in MlpExtractor.__init__(self, feature_dim, net_arch, activation_fn, device)
#     202 if pi_layer_size is not None:
#     203     assert isinstance(pi_layer_size, int), "Error: net_arch[-1]['pi'] must only contain integers."
# --> 204     policy_net.append(nn.Linear(last_layer_dim_pi, pi_layer_size))
#     205     policy_net.append(activation_fn())
#     206     last_layer_dim_pi = pi_layer_size
#
# File /mnt/d/witeo/Documents/Computer Science/FYP/Reinforcement Learning Tutorial/rlvenv_wsl/lib/python3.8/site-packages/torch/nn/modules/linear.py:96, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#      94 self.in_features = in_features
#      95 self.out_features = out_features
# ---> 96 self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
#      97 if bias:
#      98     self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
#
# TypeError: empty(): argument 'size' must be tuple of SymInts, but found element of type numpy.ndarray at pos 2

# %%
print(type(env.observation_space.spaces))

# %% [markdown]
# ## Simulation of Junction

# %%
import cityflow
eng_conf = cityflow.Engine("sample_data/jacob_config.json", thread_num=1)

# %%
for i in range(10000):
    eng_conf.next_step()
