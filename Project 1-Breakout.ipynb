# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %%
# !pip install atari_py
# Out:
# Collecting atari_py
#   Downloading atari_py-0.2.9-cp38-cp38-win_amd64.whl (1.6 MB)
# Requirement already satisfied: six in d:\witeo\documents\computer science\fyp\reinforcement learning tutorial\rltut_venv\lib\site-packages (from atari_py) (1.16.0)
# Requirement already satisfied: numpy in d:\witeo\documents\computer science\fyp\reinforcement learning tutorial\rltut_venv\lib\site-packages (from atari_py) (1.23.0)
# Installing collected packages: atari-py
# Successfully installed atari-py-0.2.9
# WARNING: You are using pip version 20.2.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'd:\witeo\documents\computer science\fyp\reinforcement learning tutorial\rltut_venv\scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # 2. Test Environment

# %%
# http://www.atarimania.com/roms/Roms.rar

# %%
# !python -m atari_py.import_roms .\Roms\ROMS
# Out:
# copying adventure.bin from .\Roms\ROMS\Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\adventure.bin
# copying air_raid.bin from .\Roms\ROMS\Air Raid (Men-A-Vision) (PAL) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\air_raid.bin
# copying alien.bin from .\Roms\ROMS\Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\alien.bin
# copying amidar.bin from .\Roms\ROMS\Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\amidar.bin
# copying assault.bin from .\Roms\ROMS\Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\assault.bin
# copying asterix.bin from .\Roms\ROMS\Asterix (AKA Taz) (1984) (Atari, Jerome Domurat, Steve Woita) (CX2696).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\asterix.bin
# copying asteroids.bin from .\Roms\ROMS\Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\asteroids.bin
# copying atlantis.bin from .\Roms\ROMS\Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\atlantis.bin
# copying bank_heist.bin from .\Roms\ROMS\Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\bank_heist.bin
# copying battle_zone.bin from .\Roms\ROMS\Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\battle_zone.bin
# copying beam_rider.bin from .\Roms\ROMS\Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\beam_rider.bin
# copying berzerk.bin from .\Roms\ROMS\Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\berzerk.bin
# copying bowling.bin from .\Roms\ROMS\Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\bowling.bin
# copying boxing.bin from .\Roms\ROMS\Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\boxing.bin
# copying breakout.bin from .\Roms\ROMS\Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\breakout.bin
# copying carnival.bin from .\Roms\ROMS\Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\carnival.bin
# copying centipede.bin from .\Roms\ROMS\Centipede (1983) (Atari - GCC) (CX2676) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\centipede.bin
# copying chopper_command.bin from .\Roms\ROMS\Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\chopper_command.bin
# copying crazy_climber.bin from .\Roms\ROMS\Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\crazy_climber.bin
# copying defender.bin from .\Roms\ROMS\Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\defender.bin
# copying demon_attack.bin from .\Roms\ROMS\Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\demon_attack.bin
# copying donkey_kong.bin from .\Roms\ROMS\Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\donkey_kong.bin
# copying double_dunk.bin from .\Roms\ROMS\Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\double_dunk.bin
# copying elevator_action.bin from .\Roms\ROMS\Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\elevator_action.bin
# copying enduro.bin from .\Roms\ROMS\Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\enduro.bin
# copying fishing_derby.bin from .\Roms\ROMS\Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\fishing_derby.bin
# copying freeway.bin from .\Roms\ROMS\Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\freeway.bin
# copying frogger.bin from .\Roms\ROMS\Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\frogger.bin
# copying frostbite.bin from .\Roms\ROMS\Frostbite (Iceman) (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\frostbite.bin
# copying galaxian.bin from .\Roms\ROMS\Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\galaxian.bin
# copying gopher.bin from .\Roms\ROMS\Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\gopher.bin
# copying gravitar.bin from .\Roms\ROMS\Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\gravitar.bin
# copying hero.bin from .\Roms\ROMS\H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\hero.bin
# copying ice_hockey.bin from .\Roms\ROMS\Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\ice_hockey.bin
# copying jamesbond.bin from .\Roms\ROMS\James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Dan Kurczewski, Louis Marbel, Kathy Von) (PB5110) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\jamesbond.bin
# copying journey_escape.bin from .\Roms\ROMS\Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\journey_escape.bin
# copying kaboom.bin from .\Roms\ROMS\Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, CAG-010, AG-010-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\kaboom.bin
# copying kangaroo.bin from .\Roms\ROMS\Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\kangaroo.bin
# copying keystone_kapers.bin from .\Roms\ROMS\Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\keystone_kapers.bin
# copying king_kong.bin from .\Roms\ROMS\King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\king_kong.bin
# copying koolaid.bin from .\Roms\ROMS\Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\koolaid.bin
# copying krull.bin from .\Roms\ROMS\Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\krull.bin
# copying kung_fu_master.bin from .\Roms\ROMS\Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\kung_fu_master.bin
# copying laser_gates.bin from .\Roms\ROMS\Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\laser_gates.bin
# copying lost_luggage.bin from .\Roms\ROMS\Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\lost_luggage.bin
# copying montezuma_revenge.bin from .\Roms\ROMS\Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\montezuma_revenge.bin
# copying mr_do.bin from .\Roms\ROMS\Mr. Do! (1983) (CBS Electronics - Individeo, Ed English) (4L4478) (PAL).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\mr_do.bin
# copying ms_pacman.bin from .\Roms\ROMS\Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\ms_pacman.bin
# copying name_this_game.bin from .\Roms\ROMS\Name This Game (Guardians of Treasure, Octopussy) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\name_this_game.bin
# copying pacman.bin from .\Roms\ROMS\Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\pacman.bin
# copying phoenix.bin from .\Roms\ROMS\Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\phoenix.bin
# copying video_pinball.bin from .\Roms\ROMS\Pinball (AKA Video Pinball) (Zellers).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\video_pinball.bin
# copying pitfall.bin from .\Roms\ROMS\Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\pitfall.bin
# copying pooyan.bin from .\Roms\ROMS\Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\pooyan.bin
# copying private_eye.bin from .\Roms\ROMS\Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\private_eye.bin
# copying qbert.bin from .\Roms\ROMS\Q-bert (1983) (Parker Brothers - Western Technologies, Dave Hampton, Tom Sloper) (PB5360) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\qbert.bin
# copying riverraid.bin from .\Roms\ROMS\River Raid (1982) (Activision, Carol Shaw) (AX-020, AX-020-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\riverraid.bin
# copying road_runner.bin from patched version of .\Roms\ROMS\Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\road_runner.bin
# copying robotank.bin from .\Roms\ROMS\Robot Tank (Robotank) (1983) (Activision, Alan Miller) (AZ-028, AG-028-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\robotank.bin
# copying seaquest.bin from .\Roms\ROMS\Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\seaquest.bin
# copying sir_lancelot.bin from .\Roms\ROMS\Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\sir_lancelot.bin
# copying skiing.bin from .\Roms\ROMS\Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\skiing.bin
# copying solaris.bin from .\Roms\ROMS\Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\solaris.bin
# copying space_invaders.bin from .\Roms\ROMS\Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\space_invaders.bin
# copying star_gunner.bin from .\Roms\ROMS\Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\star_gunner.bin
# copying surround.bin from .\Roms\ROMS\Surround (32 in 1) (Bit Corporation) (R320).bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\surround.bin
# copying tennis.bin from .\Roms\ROMS\Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\tennis.bin
# copying time_pilot.bin from .\Roms\ROMS\Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\time_pilot.bin
# copying trondead.bin from .\Roms\ROMS\TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\trondead.bin
# copying tutankham.bin from .\Roms\ROMS\Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\tutankham.bin
# copying up_n_down.bin from .\Roms\ROMS\Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\up_n_down.bin
# copying venture.bin from .\Roms\ROMS\Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\venture.bin
# copying pong.bin from .\Roms\ROMS\Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\pong.bin
# copying wizard_of_wor.bin from .\Roms\ROMS\Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\wizard_of_wor.bin
# copying yars_revenge.bin from .\Roms\ROMS\Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\yars_revenge.bin
# copying zaxxon.bin from .\Roms\ROMS\Zaxxon (1983) (Coleco) (2454) ~.bin to D:\witeo\Documents\Computer Science\FYP\Reinforcement Learning Tutorial\rltut_venv\lib\site-packages\atari_py\atari_roms\zaxxon.bin

# %%
environment_name = "Breakout-v0"

# %%
env = gym.make(environment_name, render_mode='human')

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
#         env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# env.close()
# Out:
# Episode:1 Score:2.0
# Episode:2 Score:1.0
# Episode:3 Score:3.0
# Episode:4 Score:1.0
# Episode:5 Score:2.0

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# 3

# %%
env.observation_space.sample()
# Out:
# array([[[ 69, 120,  13],
#         [  6, 141, 112],
#         [ 33, 163,  99],
#         ...,
#         [ 64, 181,  37],
#         [214, 168,  65],
#         [227,  92,  89]],
#
#        [[152, 181,  18],
#         [ 54,   4,  86],
#         [238,  58, 196],
#         ...,
#         [213, 161, 224],
#         [156,  36,  74],
#         [ 93, 219, 185]],
#
#        [[146,   3,  81],
#         [ 69, 100,  88],
#         [ 53, 180,  36],
#         ...,
#         [173, 172, 146],
#         [ 19, 111,  17],
#         [190,  44,  71]],
#
#        ...,
#
#        [[253,   7, 180],
#         [105, 187,  27],
#         [135,   1,  27],
#         ...,
#         [ 91, 146, 109],
#         [158,  70, 244],
#         [ 11, 163, 192]],
#
#        [[100, 151, 201],
#         [243, 205, 180],
#         [212,  85,  96],
#         ...,
#         [ 45,  34,  89],
#         [247, 120, 225],
#         [162, 217,  80]],
#
#        [[133, 169, 237],
#         [108, 166, 228],
#         [110, 112, 146],
#         ...,
#         [113, 103, 253],
#         [179, 193, 232],
#         [ 63,  93, 135]]], dtype=uint8)

# %% [markdown]
# # 3. Vectorise Environment and Train Model

# %%
env = make_atari_env('Breakout-v0', n_envs=4, seed=0)

# %%
env = VecFrameStack(env, n_stack=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training\Logs\A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.73     |
# | time/                 |          |
# |    fps                | 142      |
# |    iterations         | 100      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.346    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.186   |
# |    value_loss         | 0.337    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 310      |
# |    ep_rew_mean        | 2.03     |
# | time/                 |          |
# |    fps                | 120      |
# |    iterations         | 200      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.453   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0796  |
# |    value_loss         | 0.00674  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 310      |
# |    ep_rew_mean        | 2.02     |
# | time/                 |          |
# |    fps                | 116      |
# |    iterations         | 300      |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.196    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0521  |
# |    value_loss         | 0.0213   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 319      |
# |    ep_rew_mean        | 2.24     |
# | time/                 |          |
# |    fps                | 113      |
# |    iterations         | 400      |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.00826  |
# |    value_loss         | 0.0313   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 310      |
# |    ep_rew_mean        | 2.11     |
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 500      |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0356   |
# |    value_loss         | 0.00907  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 316      |
# |    ep_rew_mean        | 2.22     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 600      |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.925    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0456   |
# |    value_loss         | 0.0259   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 317      |
# |    ep_rew_mean        | 2.24     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 700      |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0173  |
# |    value_loss         | 0.0212   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 329      |
# |    ep_rew_mean        | 2.46     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 800      |
# |    time_elapsed       | 158      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.832    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.00719  |
# |    value_loss         | 0.0927   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 339      |
# |    ep_rew_mean        | 2.65     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 900      |
# |    time_elapsed       | 179      |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | -2.81    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0633  |
# |    value_loss         | 0.0124   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 338      |
# |    ep_rew_mean        | 2.65     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 1000     |
# |    time_elapsed       | 201      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0527  |
# |    value_loss         | 0.0585   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 352      |
# |    ep_rew_mean        | 2.95     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 1100     |
# |    time_elapsed       | 223      |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | 0.496    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.0602   |
# |    value_loss         | 0.0555   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 363      |
# |    ep_rew_mean        | 3.16     |
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 1200     |
# |    time_elapsed       | 247      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.867   |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0731   |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 374      |
# |    ep_rew_mean        | 3.44     |
# | time/                 |          |
# |    fps                | 95       |
# |    iterations         | 1300     |
# |    time_elapsed       | 272      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.73     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0888  |
# |    value_loss         | 0.0642   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 397      |
# |    ep_rew_mean        | 4.04     |
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 1400     |
# |    time_elapsed       | 297      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.03    |
# |    explained_variance | 0.667    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.293   |
# |    value_loss         | 0.181    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 410      |
# |    ep_rew_mean        | 4.37     |
# | time/                 |          |
# |    fps                | 92       |
# |    iterations         | 1500     |
# |    time_elapsed       | 323      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.798   |
# |    explained_variance | 0.867    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.133   |
# |    value_loss         | 0.0706   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 407      |
# |    ep_rew_mean        | 4.44     |
# | time/                 |          |
# |    fps                | 91       |
# |    iterations         | 1600     |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.719    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.152   |
# |    value_loss         | 0.0558   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 420      |
# |    ep_rew_mean        | 4.8      |
# | time/                 |          |
# |    fps                | 91       |
# |    iterations         | 1700     |
# |    time_elapsed       | 373      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.386   |
# |    explained_variance | 0.791    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.062   |
# |    value_loss         | 0.236    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 418      |
# |    ep_rew_mean        | 4.71     |
# | time/                 |          |
# |    fps                | 90       |
# |    iterations         | 1800     |
# |    time_elapsed       | 395      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.909   |
# |    explained_variance | 0.886    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.266   |
# |    value_loss         | 0.132    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 418      |
# |    ep_rew_mean        | 4.74     |
# | time/                 |          |
# |    fps                | 91       |
# |    iterations         | 1900     |
# |    time_elapsed       | 416      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.614   |
# |    explained_variance | 0.448    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.258    |
# |    value_loss         | 0.588    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 436      |
# |    ep_rew_mean        | 5.09     |
# | time/                 |          |
# |    fps                | 91       |
# |    iterations         | 2000     |
# |    time_elapsed       | 436      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.713   |
# |    explained_variance | 0.714    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.049    |
# |    value_loss         | 0.0594   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 442      |
# |    ep_rew_mean        | 5.16     |
# | time/                 |          |
# |    fps                | 92       |
# |    iterations         | 2100     |
# |    time_elapsed       | 455      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.416   |
# |    explained_variance | 0.82     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.0391   |
# |    value_loss         | 0.123    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 447      |
# |    ep_rew_mean        | 5.21     |
# | time/                 |          |
# |    fps                | 92       |
# |    iterations         | 2200     |
# |    time_elapsed       | 474      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.484   |
# |    explained_variance | 0.889    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.121   |
# |    value_loss         | 0.113    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 453      |
# |    ep_rew_mean        | 5.39     |
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 2300     |
# |    time_elapsed       | 493      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.845   |
# |    explained_variance | 0.955    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0245  |
# |    value_loss         | 0.0393   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 456      |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 93       |
# |    iterations         | 2400     |
# |    time_elapsed       | 512      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.349   |
# |    explained_variance | 0.779    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.00209 |
# |    value_loss         | 0.167    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 446      |
# |    ep_rew_mean        | 5.17     |
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 2500     |
# |    time_elapsed       | 530      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.24    |
# |    explained_variance | 0.896    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0332   |
# |    value_loss         | 0.0468   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 453      |
# |    ep_rew_mean        | 5.28     |
# | time/                 |          |
# |    fps                | 94       |
# |    iterations         | 2600     |
# |    time_elapsed       | 549      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.319   |
# |    explained_variance | 0.848    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.00826 |
# |    value_loss         | 0.0286   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 461      |
# |    ep_rew_mean        | 5.51     |
# | time/                 |          |
# |    fps                | 95       |
# |    iterations         | 2700     |
# |    time_elapsed       | 568      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.626   |
# |    explained_variance | 0.724    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.176   |
# |    value_loss         | 0.19     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 475      |
# |    ep_rew_mean        | 5.67     |
# | time/                 |          |
# |    fps                | 95       |
# |    iterations         | 2800     |
# |    time_elapsed       | 586      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.727   |
# |    explained_variance | 0.758    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.0851   |
# |    value_loss         | 0.101    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 477      |
# |    ep_rew_mean        | 5.72     |
# | time/                 |          |
# |    fps                | 95       |
# |    iterations         | 2900     |
# |    time_elapsed       | 606      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.126   |
# |    value_loss         | 0.0236   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 486      |
# |    ep_rew_mean        | 5.91     |
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 3000     |
# |    time_elapsed       | 624      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.444   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0637   |
# |    value_loss         | 0.0774   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 500      |
# |    ep_rew_mean        | 6.17     |
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 3100     |
# |    time_elapsed       | 643      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.266   |
# |    explained_variance | 0.911    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0112  |
# |    value_loss         | 0.0343   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 494      |
# |    ep_rew_mean        | 6.06     |
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 3200     |
# |    time_elapsed       | 662      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.763   |
# |    explained_variance | -10.6    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.00711  |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 482      |
# |    ep_rew_mean        | 5.89     |
# | time/                 |          |
# |    fps                | 96       |
# |    iterations         | 3300     |
# |    time_elapsed       | 681      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.665   |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0362  |
# |    value_loss         | 0.0224   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 488      |
# |    ep_rew_mean        | 5.94     |
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 3400     |
# |    time_elapsed       | 700      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.473   |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0553  |
# |    value_loss         | 0.054    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 490      |
# |    ep_rew_mean        | 5.9      |
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 3500     |
# |    time_elapsed       | 719      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.44    |
# |    explained_variance | 0.889    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0528  |
# |    value_loss         | 0.0488   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 493      |
# |    ep_rew_mean        | 5.94     |
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 3600     |
# |    time_elapsed       | 737      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.439   |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.0439  |
# |    value_loss         | 0.092    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 495      |
# |    ep_rew_mean        | 6.02     |
# | time/                 |          |
# |    fps                | 97       |
# |    iterations         | 3700     |
# |    time_elapsed       | 756      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.418   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0305  |
# |    value_loss         | 0.0622   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | 6.12     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 3800     |
# |    time_elapsed       | 774      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.428   |
# |    explained_variance | 0.783    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0525  |
# |    value_loss         | 0.0462   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 491      |
# |    ep_rew_mean        | 5.92     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 3900     |
# |    time_elapsed       | 794      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.327   |
# |    explained_variance | 0.633    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.00298 |
# |    value_loss         | 0.182    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | 6.19     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 4000     |
# |    time_elapsed       | 813      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.322   |
# |    explained_variance | 0.877    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00533 |
# |    value_loss         | 0.0905   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 504      |
# |    ep_rew_mean        | 6.2      |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 4100     |
# |    time_elapsed       | 832      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.417   |
# |    explained_variance | 0.946    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.000559 |
# |    value_loss         | 0.0353   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | 6.14     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 4200     |
# |    time_elapsed       | 851      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.587   |
# |    explained_variance | 0.916    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0232  |
# |    value_loss         | 0.0315   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 499      |
# |    ep_rew_mean        | 6.06     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 4300     |
# |    time_elapsed       | 870      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.589   |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.0153   |
# |    value_loss         | 0.0109   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 505      |
# |    ep_rew_mean        | 6.22     |
# | time/                 |          |
# |    fps                | 98       |
# |    iterations         | 4400     |
# |    time_elapsed       | 889      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.761   |
# |    explained_variance | 0.713    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.175   |
# |    value_loss         | 0.0577   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 521      |
# |    ep_rew_mean        | 6.59     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4500     |
# |    time_elapsed       | 907      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.527   |
# |    explained_variance | 0.699    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0361  |
# |    value_loss         | 0.117    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 514      |
# |    ep_rew_mean        | 6.43     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4600     |
# |    time_elapsed       | 926      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.31    |
# |    explained_variance | 0.726    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.002   |
# |    value_loss         | 0.188    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | 6.75     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4700     |
# |    time_elapsed       | 945      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.0851  |
# |    explained_variance | 0.869    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.0684   |
# |    value_loss         | 0.0329   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 535      |
# |    ep_rew_mean        | 6.93     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4800     |
# |    time_elapsed       | 964      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.561   |
# |    explained_variance | 0.759    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.026   |
# |    value_loss         | 0.0677   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 545      |
# |    ep_rew_mean        | 7.19     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 4900     |
# |    time_elapsed       | 982      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.465   |
# |    explained_variance | 0.531    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.00527  |
# |    value_loss         | 0.0955   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 546      |
# |    ep_rew_mean        | 7.27     |
# | time/                 |          |
# |    fps                | 99       |
# |    iterations         | 5000     |
# |    time_elapsed       | 1001     |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.304   |
# |    explained_variance | 0.785    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0104  |
# |    value_loss         | 0.0486   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 544      |
# |    ep_rew_mean        | 7.11     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5100     |
# |    time_elapsed       | 1019     |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -0.449   |
# |    explained_variance | 0.793    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.0504   |
# |    value_loss         | 0.0711   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 561      |
# |    ep_rew_mean        | 7.52     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5200     |
# |    time_elapsed       | 1038     |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.759   |
# |    explained_variance | 0.187    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.117    |
# |    value_loss         | 0.105    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 555      |
# |    ep_rew_mean        | 7.34     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5300     |
# |    time_elapsed       | 1058     |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -0.698   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0394  |
# |    value_loss         | 0.0953   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 548      |
# |    ep_rew_mean        | 7.15     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5400     |
# |    time_elapsed       | 1077     |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.432   |
# |    explained_variance | 0.801    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0789   |
# |    value_loss         | 0.195    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 554      |
# |    ep_rew_mean        | 7.39     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5500     |
# |    time_elapsed       | 1096     |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -0.293   |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0207   |
# |    value_loss         | 0.0474   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 566      |
# |    ep_rew_mean        | 7.55     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5600     |
# |    time_elapsed       | 1115     |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.282   |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.036    |
# |    value_loss         | 0.118    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 562      |
# |    ep_rew_mean        | 7.54     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5700     |
# |    time_elapsed       | 1134     |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -0.347   |
# |    explained_variance | 0.862    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0876  |
# |    value_loss         | 0.0383   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 552      |
# |    ep_rew_mean        | 7.4      |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5800     |
# |    time_elapsed       | 1153     |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.304   |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0189   |
# |    value_loss         | 0.0797   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 559      |
# |    ep_rew_mean        | 7.57     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 5900     |
# |    time_elapsed       | 1171     |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -0.349   |
# |    explained_variance | 0.786    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.00139 |
# |    value_loss         | 0.27     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 573      |
# |    ep_rew_mean        | 7.9      |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 6000     |
# |    time_elapsed       | 1190     |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.619   |
# |    explained_variance | 0.167    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.143    |
# |    value_loss         | 0.253    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 571      |
# |    ep_rew_mean        | 7.86     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 6100     |
# |    time_elapsed       | 1210     |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -0.391   |
# |    explained_variance | 0.673    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0986  |
# |    value_loss         | 0.163    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 569      |
# |    ep_rew_mean        | 7.7      |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 6200     |
# |    time_elapsed       | 1229     |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.268   |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.0469   |
# |    value_loss         | 0.0534   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 577      |
# |    ep_rew_mean        | 7.78     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 6300     |
# |    time_elapsed       | 1248     |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -0.333   |
# |    explained_variance | 0.496    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.173   |
# |    value_loss         | 0.176    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 580      |
# |    ep_rew_mean        | 7.81     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 6400     |
# |    time_elapsed       | 1267     |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.337   |
# |    explained_variance | 0.545    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.132    |
# |    value_loss         | 0.322    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 586      |
# |    ep_rew_mean        | 7.89     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 6500     |
# |    time_elapsed       | 1286     |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -0.774   |
# |    explained_variance | 0.781    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0482  |
# |    value_loss         | 0.0897   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 577      |
# |    ep_rew_mean        | 7.69     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 6600     |
# |    time_elapsed       | 1305     |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.402   |
# |    explained_variance | 0.795    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0132  |
# |    value_loss         | 0.0822   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 567      |
# |    ep_rew_mean        | 7.54     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 6700     |
# |    time_elapsed       | 1324     |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -0.484   |
# |    explained_variance | 0.757    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.006    |
# |    value_loss         | 0.0648   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 574      |
# |    ep_rew_mean        | 7.62     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 6800     |
# |    time_elapsed       | 1343     |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.512   |
# |    explained_variance | 0.606    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.0709  |
# |    value_loss         | 0.292    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 551      |
# |    ep_rew_mean        | 7.24     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 6900     |
# |    time_elapsed       | 1361     |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -0.52    |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.0917  |
# |    value_loss         | 0.0481   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 537      |
# |    ep_rew_mean        | 6.98     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 7000     |
# |    time_elapsed       | 1380     |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.446   |
# |    explained_variance | 0.556    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.066    |
# |    value_loss         | 0.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 541      |
# |    ep_rew_mean        | 7.03     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 7100     |
# |    time_elapsed       | 1399     |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -0.593   |
# |    explained_variance | 0.602    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.17     |
# |    value_loss         | 0.0846   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 536      |
# |    ep_rew_mean        | 6.95     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 7200     |
# |    time_elapsed       | 1418     |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.925   |
# |    explained_variance | 0.519    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.00153  |
# |    value_loss         | 0.145    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 548      |
# |    ep_rew_mean        | 7.2      |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 7300     |
# |    time_elapsed       | 1437     |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -0.652   |
# |    explained_variance | 0.61     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.004    |
# |    value_loss         | 0.076    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 546      |
# |    ep_rew_mean        | 7.15     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 7400     |
# |    time_elapsed       | 1456     |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.578   |
# |    explained_variance | 0.501    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.00773 |
# |    value_loss         | 0.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 552      |
# |    ep_rew_mean        | 7.22     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 7500     |
# |    time_elapsed       | 1475     |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -0.427   |
# |    explained_variance | 0.645    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.0369   |
# |    value_loss         | 0.324    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 570      |
# |    ep_rew_mean        | 7.53     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 7600     |
# |    time_elapsed       | 1494     |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.514   |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0505  |
# |    value_loss         | 0.0755   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 570      |
# |    ep_rew_mean        | 7.49     |
# ...
# |    entropy_loss       | -0.0933  |
# |    explained_variance | 0.653    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17499    |
# |    policy_loss        | 0.0242   |
# |    value_loss         | 0.167    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 726      |
# |    ep_rew_mean        | 11.8     |
# | time/                 |          |
# |    fps                | 104      |
# |    iterations         | 17600    |
# |    time_elapsed       | 3374     |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -0.141   |
# |    explained_variance | 0.36     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17599    |
# |    policy_loss        | 0.0042   |
# |    value_loss         | 0.366    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 729      |
# |    ep_rew_mean        | 11.9     |
# | time/                 |          |
# |    fps                | 104      |
# |    iterations         | 17700    |
# |    time_elapsed       | 3393     |
# |    total_timesteps    | 354000   |
# | train/                |          |
# |    entropy_loss       | -0.201   |
# |    explained_variance | 0.829    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | -0.0291  |
# |    value_loss         | 0.175    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 713      |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 104      |
# |    iterations         | 17800    |
# |    time_elapsed       | 3418     |
# |    total_timesteps    | 356000   |
# | train/                |          |
# |    entropy_loss       | -0.137   |
# |    explained_variance | 0.466    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | -0.022   |
# |    value_loss         | 0.562    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 684      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 104      |
# |    iterations         | 17900    |
# |    time_elapsed       | 3441     |
# |    total_timesteps    | 358000   |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | 0.962    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | 0.0325   |
# |    value_loss         | 0.0312   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 692      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 103      |
# |    iterations         | 18000    |
# |    time_elapsed       | 3466     |
# |    total_timesteps    | 360000   |
# | train/                |          |
# |    entropy_loss       | -0.0889  |
# |    explained_variance | 0.597    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 0.00868  |
# |    value_loss         | 0.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 709      |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 103      |
# |    iterations         | 18100    |
# |    time_elapsed       | 3491     |
# |    total_timesteps    | 362000   |
# | train/                |          |
# |    entropy_loss       | -0.335   |
# |    explained_variance | -0.776   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | 0.128    |
# |    value_loss         | 0.527    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 715      |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 103      |
# |    iterations         | 18200    |
# |    time_elapsed       | 3518     |
# |    total_timesteps    | 364000   |
# | train/                |          |
# |    entropy_loss       | -0.32    |
# |    explained_variance | 0.539    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18199    |
# |    policy_loss        | -0.0846  |
# |    value_loss         | 0.227    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 703      |
# |    ep_rew_mean        | 11.1     |
# | time/                 |          |
# |    fps                | 103      |
# |    iterations         | 18300    |
# |    time_elapsed       | 3544     |
# |    total_timesteps    | 366000   |
# | train/                |          |
# |    entropy_loss       | -0.305   |
# |    explained_variance | 0.159    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 0.0991   |
# |    value_loss         | 0.268    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 705      |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 103      |
# |    iterations         | 18400    |
# |    time_elapsed       | 3569     |
# |    total_timesteps    | 368000   |
# | train/                |          |
# |    entropy_loss       | -0.384   |
# |    explained_variance | 0.311    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | -0.128   |
# |    value_loss         | 0.299    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 703      |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 18500    |
# |    time_elapsed       | 3594     |
# |    total_timesteps    | 370000   |
# | train/                |          |
# |    entropy_loss       | -0.127   |
# |    explained_variance | 0.729    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.0737   |
# |    value_loss         | 0.137    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 708      |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 18600    |
# |    time_elapsed       | 3621     |
# |    total_timesteps    | 372000   |
# | train/                |          |
# |    entropy_loss       | -0.169   |
# |    explained_variance | 0.186    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 0.00613  |
# |    value_loss         | 0.467    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 712      |
# |    ep_rew_mean        | 11.6     |
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 18700    |
# |    time_elapsed       | 3646     |
# |    total_timesteps    | 374000   |
# | train/                |          |
# |    entropy_loss       | -0.256   |
# |    explained_variance | 0.806    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18699    |
# |    policy_loss        | -0.0113  |
# |    value_loss         | 0.0483   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 708      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 18800    |
# |    time_elapsed       | 3673     |
# |    total_timesteps    | 376000   |
# | train/                |          |
# |    entropy_loss       | -0.276   |
# |    explained_variance | 0.723    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | 0.0115   |
# |    value_loss         | 0.359    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 695      |
# |    ep_rew_mean        | 11.2     |
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 18900    |
# |    time_elapsed       | 3699     |
# |    total_timesteps    | 378000   |
# | train/                |          |
# |    entropy_loss       | -0.174   |
# |    explained_variance | 0.184    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | 0.0264   |
# |    value_loss         | 0.268    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 709      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 102      |
# |    iterations         | 19000    |
# |    time_elapsed       | 3724     |
# |    total_timesteps    | 380000   |
# | train/                |          |
# |    entropy_loss       | -0.171   |
# |    explained_variance | 0.472    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | -0.00131 |
# |    value_loss         | 0.299    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 724      |
# |    ep_rew_mean        | 11.8     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 19100    |
# |    time_elapsed       | 3748     |
# |    total_timesteps    | 382000   |
# | train/                |          |
# |    entropy_loss       | -0.165   |
# |    explained_variance | 0.497    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 0.0478   |
# |    value_loss         | 0.387    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 710      |
# |    ep_rew_mean        | 11.4     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 19200    |
# |    time_elapsed       | 3771     |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -0.233   |
# |    explained_variance | 0.898    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | 0.0287   |
# |    value_loss         | 0.107    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 716      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 19300    |
# |    time_elapsed       | 3795     |
# |    total_timesteps    | 386000   |
# | train/                |          |
# |    entropy_loss       | -0.31    |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | 0.00776  |
# |    value_loss         | 0.02     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 733      |
# |    ep_rew_mean        | 11.8     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 19400    |
# |    time_elapsed       | 3823     |
# |    total_timesteps    | 388000   |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | -0.0654  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | 0.187    |
# |    value_loss         | 0.214    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 733      |
# |    ep_rew_mean        | 11.6     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 19500    |
# |    time_elapsed       | 3850     |
# |    total_timesteps    | 390000   |
# | train/                |          |
# |    entropy_loss       | -0.098   |
# |    explained_variance | 0.425    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | -0.00114 |
# |    value_loss         | 0.0794   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 749      |
# |    ep_rew_mean        | 11.9     |
# | time/                 |          |
# |    fps                | 101      |
# |    iterations         | 19600    |
# |    time_elapsed       | 3876     |
# |    total_timesteps    | 392000   |
# | train/                |          |
# |    entropy_loss       | -0.309   |
# |    explained_variance | 0.854    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | -0.07    |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 756      |
# |    ep_rew_mean        | 12.2     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 19700    |
# |    time_elapsed       | 3903     |
# |    total_timesteps    | 394000   |
# | train/                |          |
# |    entropy_loss       | -0.137   |
# |    explained_variance | 0.591    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | 0.00119  |
# |    value_loss         | 0.647    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 742      |
# |    ep_rew_mean        | 11.8     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 19800    |
# |    time_elapsed       | 3927     |
# |    total_timesteps    | 396000   |
# | train/                |          |
# |    entropy_loss       | -0.301   |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19799    |
# |    policy_loss        | 0.0601   |
# |    value_loss         | 0.0747   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 748      |
# |    ep_rew_mean        | 12.2     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 19900    |
# |    time_elapsed       | 3951     |
# |    total_timesteps    | 398000   |
# | train/                |          |
# |    entropy_loss       | -0.18    |
# |    explained_variance | 0.832    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | -0.0374  |
# |    value_loss         | 0.379    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 749      |
# |    ep_rew_mean        | 12.3     |
# | time/                 |          |
# |    fps                | 100      |
# |    iterations         | 20000    |
# |    time_elapsed       | 3976     |
# |    total_timesteps    | 400000   |
# | train/                |          |
# |    entropy_loss       | -0.334   |
# |    explained_variance | -0.0553  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | 0.0189   |
# |    value_loss         | 0.439    |
# ------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'A2C_400k_model')

# %%
model.save(a2c_path)

# %%
del model

# %%
env = make_atari_env('Breakout-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)

# %%
make_atari_env??

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy??

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# (13.5, 4.410215414239989)

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-24-c9313fcdef63> in <module>
#       3     action, _states = model.predict(obs)
#       4     obs, rewards, dones, info = env.step(action)
# ----> 5     env.render()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in render(self, mode)
#     279
#     280     def render(self, mode: str = "human") -> Optional[np.ndarray]:
# --> 281         return self.venv.render(mode=mode)
#     282
#     283     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in render(self, mode)
#      83         """
#      84         if self.num_envs == 1:
# ---> 85             return self.envs[0].render(mode=mode)
#      86         else:
#      87             return super().render(mode=mode)
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\envs\atari\environment.py in render(self, mode)
#     281             return self.ale.getScreenRGB()
#     282         elif mode == "human":
# --> 283             raise error.Error(
#     284                 (
#     285                     "render(mode='human') is deprecated. Please supply `render_mode` when "
#
# Error: render(mode='human') is deprecated. Please supply `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). The new `render_mode` keyword argument supports DPI scaling, audio, and native framerates.

# %%
env.close()
